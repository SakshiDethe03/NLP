# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp("Sometimes, the smallest step in the dark, becomes the beginning of a great journey.")

for sentence in doc.sents:
    print(sentence)
# Out:
# Sometimes, the smallest step in the dark, becomes the beginning of a great journey.

# %%
for sentence in doc.sents:
    for word in sentence:
        print(word)
# Out:
# Sometimes
# ,
# the
# smallest
# step
# in
# the
# dark
# ,
# becomes
# the
# beginning
# of
# a
# great
# journey
# .

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\SAKSHI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

sent_tokenize("Sometimes, the smallest step in the dark becomes the beginning of a great journey.")
# Out:
# ['Sometimes, the smallest step in the dark becomes the beginning of a great journey.']

# %%
nlp = spacy.blank("en")

doc = nlp("Tony gave two $ to peter.")

for token in doc:
    print(token)
# Out:
# Tony
# gave
# two
# $
# to
# peter
# .

# %%
token0 = doc[0]
token0
# Out:
# Tony

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
# ...

# %%
token0.is_alpha
# Out:
# True

# %%
token3 = doc[3]
token3.text
# Out:
# '$'

# %%
token3.like_num
# Out:
# False

# %%
for token in doc:
    print(token, "==>", "index: ", token.i, 
          "is_alpha: ", token.is_alpha, 
          "like_num: ", token.like_num, 
          "is_currency: ", token.is_currency, 
         )
# Out:
# Tony ==> index:  0 is_alpha:  True like_num:  False is_currency:  False
# gave ==> index:  1 is_alpha:  True like_num:  False is_currency:  False
# two ==> index:  2 is_alpha:  True like_num:  True is_currency:  False
# $ ==> index:  3 is_alpha:  False like_num:  False is_currency:  True
# to ==> index:  4 is_alpha:  True like_num:  False is_currency:  False
# peter ==> index:  5 is_alpha:  True like_num:  False is_currency:  False
# . ==> index:  6 is_alpha:  False like_num:  False is_currency:  False

# %%
with open("students.txt") as f:
    text = f.readlines()

text
# Out:
# ['\n',
#  'Name\tClass\tRollNo\tCourse  email  \n',
#  'Aa\tSY\t3\tcomputer science   aaa@gmail.com\n',
#  'Bb\tTY\t1\tartificial intelligence  bbb@gmail.com\n',
#  'Cc  SY  2   computer science   ccc@gmail.com']

# %%
text = ' '.join(text)
text
# Out:
# '\n Name\tClass\tRollNo\tCourse  email  \n Aa\tSY\t3\tcomputer science   aaa@gmail.com\n Bb\tTY\t1\tartificial intelligence  bbb@gmail.com\n Cc  SY  2   computer science   ccc@gmail.com'

# %%
doc = nlp(text)
emails = []

for token in doc:
    if token.like_email:
        emails.append(token.text)
emails
# Out:
# ['aaa@gmail.com', 'bbb@gmail.com', 'ccc@gmail.com']

# %%
doc = nlp(text)
num = []

for token in doc:
    if token.like_num:
        num.append(token)
num
# Out:
# [3, 1, 2]

# %%
nlp_mr = spacy.blank("mr")

doc_mr = nlp("नमस्कार, तुम्ही ५०० $ परत केले नाही हा...")

for token in doc_mr:
    print(token, token.is_currency, token.like_num)
# Out:
# नमस्कार False False
# , False False
# तुम्ही False False
# ५०० False True
# $ True False
# परत False False
# केले False False
# नाही False False
# हा False False
# ... False False

# %%
doc = nlp("gimme double cheese extra large healthy pizza")

tokens = [token.text for token in doc]
tokens
# Out:
# ['gimme', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
from spacy.symbols import ORTH

nlp.tokenizer.add_special_case("gimme", [
    {ORTH: "gim"},
    {ORTH: "me"}
])

doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
nlp.add_pipe('sentencizer')

# %%
nlp.pipe_names
# Out:
# ['sentencizer']

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")

for sentence in doc.sents:
    print(sentence)
# Out:
# Dr. Strange loves pav bhaji of mumbai.
# Hulk loves chat of delhi

# %%
text = '''
Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/, 
and the European Social Survey at http://www.europeansocialsurvey.org/.
'''

doc = nlp(text)
urls = []

for token in doc:
    if token.like_url:
        urls.append(token.text)
urls
# Out:
# ['http://www.data.gov/',
#  'http://www.science',
#  'http://data.gov.uk/.',
#  'http://www3.norc.org/gss+website/',
#  'http://www.europeansocialsurvey.org/.']

# %%
transactions = "Tony gave two $ to Peter, Bruce gave 500 € to Steve"
num = []
currency = []

doc = nlp(transactions)

for token in doc:
    if (token.like_num or token.is_currency):
        num.append(token.text)
        currency.append(token.text)
num
currency
# Out:
# ['two', '$', '500', '€']
