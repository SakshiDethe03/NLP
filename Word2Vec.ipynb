# %% [markdown]
# ## Word2Vec in gensim

# %%
# !pip install gensim
# !pip install python-Levenshtein
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from gensim) (2.4.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from gensim) (1.17.1)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/python/3.12.1/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim) (2.1.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 25.0 MB/s  0:00:01m0:00:0100:01
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import gensim
import pandas as pd

# %%
df = pd.read_json("reviews_Cell_Phones_and_Accessories_5.json", lines=True)

# %%
df.shape

# %%
df.reviewText[0]

# %%
review_text = df.reviewText.apply(gensim.utils.simple_preprocess)
review_text

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2,
    workers = 4
)

# %%
model.build_vocab(review_text, progress_per = 1000)

# %%
model.epochs

# %%
model.train(review_text, total_examples = model.corpus_count, epochs = model.epochs)

# %%
model.save("./GitHub/NLP.model")

# %%
model.wv.most_similar("bad")

# %%
model.wv.similarity(w1 = "cheap", w2="inexpensive")

# %%
model.wv.similarity(w1="great", w2="awesome")
