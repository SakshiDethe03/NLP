# %% [markdown]
# ## Text Representation: label and One Hot Encoding
#
# This is used to represent labels into the vectors
#
# #### One Hot Encoding
#
# ![image.png](attachment:image.png)
#
# ### Label Encoding
#
# ![image-2.png](attachment:image-2.png)
#
# ### Disadvantages of this two methods
# 1. Consumes lot of memory
# 2. Similar words do not have similar representation
# 3. Out of Vocabulary Problem
# 4. No fixed length representation
#
#         -> like Sen1 = I need banana, then size = 3000.
#         -> Sen2 = I need banana shake, then size = 4000.
#
#       So it contains different sizes for each neuron but ML model don't support this.
